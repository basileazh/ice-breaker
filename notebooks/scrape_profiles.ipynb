# %%
from ice_breaker.services.twitter_apify import download_twitter_profile
from ice_breaker.services.linkedin import download_linkedin_profile

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
res = download_twitter_profile("ylecun", clean_profile=False)
res
# Out:
# 2023-12-13 17:32:11,864 - ice_breaker.core.log - INFO - Scraping Twitter data for ylecun...
# INFO:ice_breaker.core.log:Scraping Twitter data for ylecun...
# INFO:httpx:HTTP Request: POST https://api.apify.com/v2/acts/quacker~twitter-scraper/runs "HTTP/1.1 201 Created"
# INFO:httpx:HTTP Request: GET https://api.apify.com/v2/actor-runs/rUu1msHFGU68QV0N8?waitForFinish=999999 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.apify.com/v2/actor-runs/rUu1msHFGU68QV0N8?waitForFinish=999999 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.apify.com/v2/datasets/BedjVHg6LKFB3LyYs/items "HTTP/1.1 200 OK"
# ...

# %%
res = download_linkedin_profile("https://www.linkedin.com/in/yann-lecun/", clean_profile=False)
res
# Out:
# {'public_identifier': 'yann-lecun',
#  'profile_pic_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/person/yann-lecun/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20231213%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20231213T173328Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=6c25054f13432b590cabfcadba30ede8d6c00b7b64b1d8e3ec88ee093d44f9cb',
#  'background_cover_image_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/person/yann-lecun/cover?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20231213%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20231213T173328Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=2aaf84e492d38c36295d0a345fb60ca0124ba944110c18369f554436cd091721',
#  'first_name': 'Yann',
#  'last_name': 'LeCun',
#  'full_name': 'Yann LeCun',
#  'follower_count': 600502,
#  'occupation': 'VP & Chief AI Scientist at Meta at Facebook',
# ...
